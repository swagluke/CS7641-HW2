# %%
# !pip install mlrose_hiive
# Out:
# Collecting mlrose_hiive
#   Downloading https://files.pythonhosted.org/packages/e3/ba/75f9e6b421a8a7fc1bb91ee72d5ae27fe381828d8df7fc0869654b295729/mlrose_hiive-2.1.3.tar.gz (48kB)
#      |████████████████████████████████| 51kB 1.7MB/s eta 0:00:011
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from mlrose_hiive) (1.18.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from mlrose_hiive) (1.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from mlrose_hiive) (0.22.2.post1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from mlrose_hiive) (1.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from mlrose_hiive) (2.5)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from mlrose_hiive) (0.16.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->mlrose_hiive) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->mlrose_hiive) (2.8.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx->mlrose_hiive) (4.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas->mlrose_hiive) (1.15.0)
# Building wheels for collected packages: mlrose-hiive
#   Building wheel for mlrose-hiive (setup.py) ... done
#   Created wheel for mlrose-hiive: filename=mlrose_hiive-2.1.3-cp36-none-any.whl size=96601 sha256=a5c275432c35dc79acdbbb404954102004ff245cc939d74d17821aa8b61f1200
#   Stored in directory: /root/.cache/pip/wheels/ee/ef/8b/941402c2014649279f68a1ed4a37b4d15142dfb9c7e4a6b7ac
# Successfully built mlrose-hiive
# Installing collected packages: mlrose-hiive
# Successfully installed mlrose-hiive-2.1.3

# %%
import time
import mlrose_hiive
import numpy as np
import pandas as pd
np.random.seed(44)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Define a Fitness Function

# %%
rhc_run_stats = pd.read_pickle("/content/drive/My Drive/HW2/pickles/n_queen_rhc_run_stats.pkl")
rhc_run_curves = pd.read_pickle("/content/drive/My Drive/HW2/pickles/n_queen_rhc_run_curves.pkl")
sa_run_stats = pd.read_pickle("/content/drive/My Drive/HW2/pickles/n_queen_sa_run_stats.pkl")
sa_run_curves = pd.read_pickle("/content/drive/My Drive/HW2/pickles/n_queen_sa_run_curves.pkl")
ga_run_stats = pd.read_pickle("/content/drive/My Drive/HW2/pickles/n_queen_ga_run_stats.pkl")
ga_run_curves = pd.read_pickle("/content/drive/My Drive/HW2/pickles/n_queen_ga_run_curves.pkl")
mmc_run_stats = pd.read_pickle("/content/drive/My Drive/HW2/pickles/n_queen_mmc_run_stats.pkl")
mmc_run_curves = pd.read_pickle("/content/drive/My Drive/HW2/pickles/n_queen_mmc_run_curves.pkl")

# rhc_run_stats = pd.read_pickle("./pickles/n_queen_rhc_run_stats.pkl")
# rhc_run_curves = pd.read_pickle("./pickles/n_queen_rhc_run_curves.pkl")
# sa_run_stats = pd.read_pickle("./pickles/n_queen_sa_run_stats.pkl")
# sa_run_curves = pd.read_pickle("./pickles/n_queen_sa_run_curves.pkl")
# ga_run_stats = pd.read_pickle("./pickles/n_queen_ga_run_stats.pkl")
# ga_run_curves = pd.read_pickle("./pickles/n_queen_ga_run_curves.pkl")
# mmc_run_stats = pd.read_pickle("./pickles/n_queen_mmc_run_stats.pkl")
# mmc_run_curves = pd.read_pickle("./pickles/n_queen_mmc_run_curves.pkl")

# %%
# define alternative N-Queens fitness function for maximization prob.
def queeens_max(state):
    fitness_cnt = 0
    for i in range(len(state)-1):
        for j in range(i+1, len(state)):
            # check for attacking pairs
            if (state[j] != state[i]) \
                and (state[j] != state[i] + (j-i)) \
                and (state[j] != state[i] - (j-i)):
                
                # if noa attack
                fitness_cnt +=1

    return fitness_cnt

fitness_cust = mlrose_hiive.CustomFitness(queeens_max)

# %% [markdown]
# ## Define an Optimization Problem Object
# We use the fitness function as input into the optimization problem
#
# __TSPOpt() descrive TSP optimization__

# %%
possible_attack = 0
number_of_queens = 32
for i in range(number_of_queens,0,-1):
    possible_attack += i
possible_attack
# Out:
# 528

# %% [markdown]
# ### Random Hill Climb

# %%
# %%time
start_time = time.time()
# DiscreteOpt() takes integers in range 0 to max_val-1
problem = mlrose_hiive.DiscreteOpt(length = number_of_queens, fitness_fn = fitness_cust, 
                             maximize = True, max_val = number_of_queens)
runner_return = mlrose_hiive.RHCRunner(problem, experiment_name="first_try", 
                                       iteration_list=[10000],
                                       seed=44, max_attempts=100, 
                                       restart_list=[100])
rhc_run_stats, rhc_run_curves = runner_return.run()
end_time = time.time()
run_time = end_time - start_time
# Out:
# Running rhc
# *****************
# *** Run START ***
# *****************
# restarts:[100], max_iters:[10000], current_restart:[0]
# runner_name:[rhc], experiment_name:[first_try], attempt:[0], iteration:[0], done:[False], time:[0.00], fitness:[455.0000]
# 	[20  3 17 13 27  3  0 20  3 15 10 24 23 23 22 25  3  7  3  3  6 13 21  4// 21 25  1 14 24  7  4 29]...
#
# restarts:[100], max_iters:[10000], current_restart:[0]
# runner_name:[rhc], experiment_name:[first_try], attempt:[101], iteration:[247], done:[True], time:[0.22], fitness:[488.0000]
# 	[ 8  3 17 13 27  0 26 16 30 28 10 24  9  2 15 25 20  7 29  3  6 12 31 11// 21 30 19 14 24  1  4 23]...
#
# restarts:[100], max_iters:[10000], current_restart:[1]
# runner_name:[rhc], experiment_name:[first_try], attempt:[0], iteration:[0], done:[False], time:[0.23], fitness:[449.0000]
# 	[ 9 18 17 18 14  1  2 13 13 11 11  3  0  3  2 26 15  9 14 13 18 23  5  4// 12 13 30 10 27 12 25 14]...
#
# restarts:[100], max_iters:[10000], current_restart:[1]
# runner_name:[rhc], experiment_name:[first_try], attempt:[101], iteration:[287], done:[True], time:[0.49], fitness:[487.0000]
# 	[ 9 18 26 22  7 28 14 29 15 22 11  3 17  6  2 26 23  8 24 16 20 31  4  4// 10 21 30  5 27  0 25 12]...
#
# restarts:[100], max_iters:[10000], current_restart:[2]
# runner_name:[rhc], experiment_name:[first_try], attempt:[0], iteration:[0], done:[False], time:[0.49], fitness:[458.0000]
# 	[25 17 11 24 27 25 25 25 10 24 10  7 22 15 12  4 17  7  9  5  8 17 21 17// 23 31 23 10  3 24 24  1]...
#
# restarts:[100], max_iters:[10000], current_restart:[2]
# runner_name:[rhc], experiment_name:[first_try], attempt:[101], iteration:[246], done:[True], time:[0.69], fitness:[486.0000]
# 	[25 17 11  6 27 25 20 31 13 24  2 29 22 15 12  4  7 28  9  5 16 14 21 17//  0 31 23 10  3 30 24  1]...
#
# restarts:[100], max_iters:[10000], current_restart:[3]
# runner_name:[rhc], experiment_name:[first_try], attempt:[0], iteration:[0], done:[False], time:[0.70], fitness:[453.0000]
# 	[11 20 28 18 19 19  7 29 13  2 24  0 18  1  2 16 17 28 17 15 28 17 20 26// 10 17 28 23 27  6 21 27]...
#
# restarts:[100], max_iters:[10000], current_restart:[3]
# runner_name:[rhc], experiment_name:[first_try], attempt:[101], iteration:[298], done:[True], time:[0.98], fitness:[491.0000]
# 	[ 9 11 15 22  4 19  7 29 13  2 27  3 18 31  2  4 23 14  8 14 28 17 20 26// 10 12 28  5  1  6 21 30]...
#
# restarts:[100], max_iters:[10000], current_restart:[4]
# runner_name:[rhc], experiment_name:[first_try], attempt:[0], iteration:[0], done:[False], time:[0.98], fitness:[466.0000]
# 	[19 17 27 13 25  0 22 29 14  4  0 24 25 21 18  8 15 31 14 12  8  7 11  3// 21 11 24 19 20 21  5  6]...
#
# restarts:[100], max_iters:[10000], current_restart:[4]
# runner_name:[rhc], experiment_name:[first_try], attempt:[101], iteration:[444], done:[True], time:[1.40], fitness:[490.0000]
# 	[19 17 27 13 22  7  3 29  9 12  0  2 25 25 18  8 15 31 14 27  2  4 11 30// 10 26 24  3 28 23  5 16]...
#
# restarts:[100], max_iters:[10000], current_restart:[5]
# runner_name:[rhc], experiment_name:[first_try], attempt:[0], iteration:[0], done:[False], time:[1.41], fitness:[438.0000]
# 	[14  6 10 27 10 10 12 27 25 14  4 13 22 27 28  0  8 14 24 10  7 18  8 17// 10 24 13  8 10  3 27  0]...
#
# restarts:[100], max_iters:[10000], current_restart:[5]
# runner_name:[rhc], experiment_name:[first_try], attempt:[101], iteration:[232], done:[True], time:[1.63], fitness:[485.0000]
# 	[21 20 29 23  6  4 12 16 25  5  2 31 22 28 30  0 11 14  7 10 28 16  8 17// 22 25 13  8 10  3 19 24]...
#
# restarts:[100], max_iters:[10000], current_restart:[6]
# runner_name:[rhc], experiment_name:[first_try], attempt:[0], iteration:[0], done:[False], time:[1.64], fitness:[464.0000]
# 	[31 25 10 19  7 18  7  3 18 24  3  9 11 22 14 21  5 18 22 23 27 31 17 17//  2 26  5 21  9 29  9  4]...
#
# restarts:[100], max_iters:[10000], current_restart:[6]
# runner_name:[rhc], experiment_name:[first_try], attempt:[101], iteration:

# runner_name:[rhc], experiment_name:[first_try], attempt:[0], iteration:[0], done:[False], time:[71.61], fitness:[459.0000]
# 	[ 7 24 17 22  6 18 30 17 13 18  1 24 28 31 12 18 31  0 12 19 13 17 22 21//  9  8 16 25  7  5  4  7]...
#
# restarts:[100], max_iters:[10000], current_restart:[95]
# runner_name:[rhc], experiment_name:[first_try], attempt:[101], iteration:[504], done:[True], time:[73.31], fitness:[493.0000]
# 	[23 11 14 22  6 27 30 15 13  5  1  2 28 31 29 24 13  0 12 19  8 20 15  3//  9 26 16 25  7 21  4 17]...
#
# restarts:[100], max_iters:[10000], current_restart:[96]
# runner_name:[rhc], experiment_name:[first_try], attempt:[0], iteration:[0], done:[False], time:[73.36], fitness:[449.0000]
# 	[ 6 23  5 16 26 28  8 25 29  7 11 26 31  7  0 18 30 20  5 20 17 27 15 16// 22 28 28 17 26 25 22 15]...
#
# restarts:[100], max_iters:[10000], current_restart:[96]
# runner_name:[rhc], experiment_name:[first_try], attempt:[101], iteration:[274], done:[True], time:[74.31], fitness:[488.0000]
# 	[ 6 12 10 16  4 22 24 25  1  8 11  7 31 29 21 18 30  8 13  9  2  3 15 27//  5 28  0 17 26 31 22 14]...
#
# restarts:[100], max_iters:[10000], current_restart:[97]
# runner_name:[rhc], experiment_name:[first_try], attempt:[0], iteration:[0], done:[False], time:[74.37], fitness:[461.0000]
# 	[ 6 29 28  1 10 20 12  4 26 22 15 18  6 11 11  4  9 30 14 29 23 30 23  9// 19  8 23 13 12  7 13 10]...
#
# restarts:[100], max_iters:[10000], current_restart:[97]
# runner_name:[rhc], experiment_name:[first_try], attempt:[101], iteration:[284], done:[True], time:[75.35], fitness:[486.0000]
# 	[ 6 29 21  5 16  8 28  1 26  0 15  7 16 11 24  4 23 30 14 18 20 30 23  9// 19  8  3 17 12  7 27 10]...
#
# restarts:[100], max_iters:[10000], current_restart:[98]
# runner_name:[rhc], experiment_name:[first_try], attempt:[0], iteration:[0], done:[False], time:[75.41], fitness:[470.0000]
# 	[13  9  4  5 26 15 10 24 25 19 26  8 27  9 18  4  1 10 19  5 23  4  9 22// 31 28 20  2 24 14  5 10]...
#
# restarts:[100], max_iters:[10000], current_restart:[98]
# runner_name:[rhc], experiment_name:[first_try], attempt:[101], iteration:[464], done:[True], time:[77.02], fitness:[491.0000]
# 	[13 25 16 14 26 15 15  0 25 21 30  8 27  1 18 23  0 17 19  5  3  4  9 22// 31 28 20  2 24  6 12 10]...
#
# restarts:[100], max_iters:[10000], current_restart:[99]
# runner_name:[rhc], experiment_name:[first_try], attempt:[0], iteration:[0], done:[False], time:[77.08], fitness:[457.0000]
# 	[ 7 15  1 16  3  3 16 28 16  8 25  5 28 17 20 15 28 14 22 18 22 30 29 22// 10 13 23  6  2 29  3 27]...
#
# restarts:[100], max_iters:[10000], current_restart:[99]
# runner_name:[rhc], experiment_name:[first_try], attempt:[101], iteration:[261], done:[True], time:[78.01], fitness:[487.0000]
# 	[ 7 15 21 23  1  3 16 18  9  8 25 29 28 17 20  0 27 11 31  5 22 30 24 16// 12 13 26  4  2 19  3 27]...
#
# restarts:[100], max_iters:[10000], current_restart:[100]
# runner_name:[rhc], experiment_name:[first_try], attempt:[0], iteration:[0], done:[False], time:[78.07], fitness:[466.0000]
# 	[10  6  3 11  1  8 14  0 13  1  5 20 26 30 24 21 11 31 11 16  3 21 31 29// 13 16  8 17  9 26 27 25]...
#
# restarts:[100], max_iters:[10000], current_restart:[100]
# runner_name:[rhc], experiment_name:[first_try], attempt:[101], iteration:[448], done:[True], time:[79.66], fitness:[487.0000]
# 	[10  6  3 22 15  8 14 29 12  7 23 20 26 30  0 27 11 31 11 16  3 21  4 29// 13 24  8 17  2  1  9 25]...
#
# ***************
# *** Run END ***
# ***************
# Run time: 79.718682248
# CPU times: user 1min 19s, sys: 425 ms, total: 1min 20s
# Wall time: 1min 19s

# %%
rhc_run_stats
# Out:
#      Iteration  Fitness       Time  ... Restarts  max_iters  current_restart
# 0            0    455.0   0.003580  ...      100      10000                0
# 1        10000    488.0   0.224388  ...      100      10000                0
# 2            0    449.0   0.230400  ...      100      10000                1
# 3        10000    487.0   0.484895  ...      100      10000                1
# 4            0    458.0   0.490347  ...      100      10000                2
# ..         ...      ...        ...  ...      ...        ...              ...
# 197      10000    491.0  73.336854  ...      100      10000               98
# 198          0    457.0  73.388534  ...      100      10000               99
# 199      10000    487.0  74.276904  ...      100      10000               99
# 200          0    466.0  74.329193  ...      100      10000              100
# 201      10000    487.0  75.836642  ...      100      10000              100
#
# [202 rows x 7 columns]

# %%
rhc_run_curves
# Out:
#        Iteration       Time  Fitness  Restarts  max_iters  current_restart
# 0              0   0.003580    455.0       100      10000                0
# 1              1   0.005225    455.0       100      10000                0
# 2              2   0.006149    455.0       100      10000                0
# 3              3   0.007032    455.0       100      10000                0
# 4              4   0.008108    460.0       100      10000                0
# ...          ...        ...      ...       ...        ...              ...
# 34421      34421  75.488130    487.0       100      10000              100
# 34422      34422  75.491381    487.0       100      10000              100
# 34423      34423  75.494690    487.0       100      10000              100
# 34424      34424  75.497923    487.0       100      10000              100
# 34425      34425  75.501432    487.0       100      10000              100
#
# [34426 rows x 6 columns]

# %%
best_index_in_curve = rhc_run_curves.Fitness.idxmax()
best_decay = rhc_run_curves.iloc[best_index_in_curve].current_restart
best_curve = rhc_run_curves.loc[rhc_run_curves.current_restart == best_decay, :]
best_curve.reset_index(inplace=True)
best_decay
# Out:
# 8.0

# %%
ax = best_curve.Fitness.plot(lw=2, colormap='jet', marker='.', markersize=2, 
                             figsize=(12,8), grid=1,
                             title='Best RHC Random Search Learning Curve')
ax.set_xlabel("Iterations")
ax.set_ylabel("Fitness Value")
# Out:
# Text(0, 0.5, 'Fitness Value')

# %%
last_iters = rhc_run_stats[rhc_run_stats.Iteration != 0].reset_index()
print("Avg Fitness: " +  str(last_iters.Fitness.mean()))
print("Max Fitness: " +  str(last_iters.Fitness.max()))
print("Avg Time: " +  str(last_iters.Time.mean()))
print("Max Time: " + str(last_iters.Time.max()))
# Out:
# Avg Fitness: 488.3960396039604
# Max Fitness: 494.0
# Avg Time: 29.198142356812053
# Max Time: 72.62604274299974

# %% [markdown]
# ## Simulated Annealing

# %%
# %%time
sa = mlrose_hiive.SARunner(problem, experiment_name="SA_Exp", 
                           iteration_list=[100000],
                           temperature_list=[1, 10, 50, 100, 250, 500, 1000, 2500, 5000],
                           decay_list=[mlrose_hiive.ExpDecay,
                                       mlrose_hiive.GeomDecay],
                           seed=44, max_attempts=100)

sa_run_stats, sa_run_curves = sa.run()
# Out:
# Running sa
# *****************
# *** Run START ***
# *****************
# schedule:[1], max_iters:[100000]
# runner_name:[sa], experiment_name:[SA_Exp], attempt:[0], iteration:[0], done:[False], time:[0.00], fitness:[455.0000]
# 	[20  3 17 13 27  3  0 20  3 15 10 24 23 23 22 25  3  7  3  3  6 13 21  4// 21 25  1 14 24  7  4 29]...
#
# schedule:[1], max_iters:[100000]
# runner_name:[sa], experiment_name:[SA_Exp], attempt:[101], iteration:[3225], done:[True], time:[2.88], fitness:[495.0000]
# 	[28 22  9 14  3 19 16  1  4 29 25  4 15 26  2 27 21 23  8 17 12 10  7 20// 24  0 30 18  6 31 11 13]...
#
# ***************
# *** Run END ***
# ***************
# *****************
# *** Run START ***
# *****************
# schedule:[1], max_iters:[100000]
# runner_name:[sa], experiment_name:[SA_Exp], attempt:[0], iteration:[0], done:[False], time:[0.00], fitness:[455.0000]
# 	[20  3 17 13 27  3  0 20  3 15 10 24 23 23 22 25  3  7  3  3  6 13 21  4// 21 25  1 14 24  7  4 29]...
#
# schedule:[1], max_iters:[100000]
# runner_name:[sa], experiment_name:[SA_Exp], attempt:[101], iteration:[1343], done:[True], time:[1.20], fitness:[494.0000]
# 	[ 9 31 19 24 14  0  4  8 23 15 12  3 16 26  2  2  7 29  1 17 25  5 21 30// 27 10 22  6 28 18 20 13]...
#
# ***************
# *** Run END ***
# ***************
# *****************
# *** Run START ***
# *****************
# schedule:[10], max_iters:[100000]
# runner_name:[sa], experiment_name:[SA_Exp], attempt:[0], iteration:[0], done:[False], time:[0.00], fitness:[455.0000]
# 	[20  3 17 13 27  3  0 20  3 15 10 24 23 23 22 25  3  7  3  3  6 13 21  4// 21 25  1 14 24  7  4 29]...
#
# schedule:[10], max_iters:[100000]
# runner_name:[sa], experiment_name:[SA_Exp], attempt:[101], iteration:[
], max_iters:[100000]
# runner_name:[sa], experiment_name:[SA_Exp], attempt:[0], iteration:[0], done:[False], time:[0.00], fitness:[455.0000]
# 	[20  3 17 13 27  3  0 20  3 15 10 24 23 23 22 25  3  7  3  3  6 13 21  4// 21 25  1 14 24  7  4 29]...
#
# schedule:[5000], max_iters:[100000]
# runner_name:[sa], experiment_name:[SA_Exp], attempt:[101], iteration:[1884], done:[True], time:[2.10], fitness:[493.0000]
# 	[21 14 27  1 24 28  5 16 12 17  7 25 18  9  0 26 31  2 20 29  4 22 13  3// 10 30 19 15 11 23 19  6]...
#
# ***************
# *** Run END ***
# ***************
# Run time: 43.95296914700003
# CPU times: user 44 s, sys: 295 ms, total: 44.3 s
# Wall time: 44 s

# %%
best_index_in_curve = sa_run_curves.Fitness.idxmax()
best_decay = sa_run_curves.iloc[best_index_in_curve].Temperature
best_curve = sa_run_curves.loc[sa_run_curves.Temperature == best_decay, :]
best_curve.reset_index(inplace=True)
best_decay
# Out:
# ExpDecay(init_temp=1, exp_const=0.005, min_temp=0.001)

# %%
sa_run_curves
# Out:
#        Iteration      Time  Fitness Temperature  max_iters
# 0              0  0.001407    455.0           1     100000
# 1              1  0.003108    455.0           1     100000
# 2              2  0.004607    460.0           1     100000
# 3              3  0.006166    461.0           1     100000
# 4              4  0.007703    461.0           1     100000
# ...          ...       ...      ...         ...        ...
# 40413      40413  2.085770    493.0        5000     100000
# 40414      40414  2.086664    493.0        5000     100000
# 40415      40415  2.087520    493.0        5000     100000
# 40416      40416  2.088408    493.0        5000     100000
# 40417      40417  2.089265    493.0        5000     100000
#
# [40418 rows x 5 columns]

# %%
ax = best_curve.Fitness.plot(lw=2, colormap='jet', marker='.', markersize=2, 
                             figsize=(12,8), grid=1,
                             title='Best Simulated Annealing')
ax.set_xlabel("Iterations")
ax.set_ylabel("Fitness Value")
# Out:
# Text(0, 0.5, 'Fitness Value')

# %%
last_iters = sa_run_stats[sa_run_stats.Iteration != 0].reset_index()
print("Avg Fitness: " +  str(last_iters.Fitness.mean()))
print("Max Fitness: " +  str(last_iters.Fitness.max()))
print("Avg Time: " +  str(last_iters.Time.mean()))
print("Max Time: " + str(last_iters.Time.max()))
# Out:
# Avg Fitness: 493.72222222222223
# Max Fitness: 495.0
# Avg Time: 2.4069853731111106
# Max Time: 4.564456431999986

# %%
print(last_iters.loc[last_iters.schedule_init_temp == 1, "Time"].mean())
print(last_iters.loc[last_iters.schedule_init_temp == 10, "Time"].mean())
print(last_iters.loc[last_iters.schedule_init_temp == 50, "Time"].mean())
print(last_iters.loc[last_iters.schedule_init_temp == 100, "Time"].mean())
print(last_iters.loc[last_iters.schedule_init_temp == 250, "Time"].mean())
print(last_iters.loc[last_iters.schedule_init_temp == 500, "Time"].mean())
print(last_iters.loc[last_iters.schedule_init_temp == 1000, "Time"].mean())
print(last_iters.loc[last_iters.schedule_init_temp == 2500, "Time"].mean())
print(last_iters.loc[last_iters.schedule_init_temp == 5000, "Time"].mean())

print(last_iters.loc[:, "Time"].mean())
# Out:
# 1.818287542500002
# 1.3702820275002523
# 1.5191186014999403
# 2.308256382500076
# 2.5823575790000177
# 1.9132341414997427
# 2.6018512329997066
# 3.048468047500137
# 2.4615974570001526
# 2.180383668000003

# %% [markdown]
# ## Genetic Alg

# %%
# %%time
ga = mlrose_hiive.GARunner(problem=problem,
                          experiment_name="GA_Exp",
                          seed=44,
                          iteration_list=[100000],
                          max_attempts=100,
                          population_sizes=[50, 200, 500],
                          mutation_rates=[0.1, 0.25, 0.5])
ga_run_stats, ga_run_curves = ga.run()
# Out:
# Running ga
# *****************
# *** Run START ***
# *****************
# pop_size:[50], mutation_prob:[0.1], max_iters:[100000]
# runner_name:[ga], experiment_name:[GA_Exp], attempt:[0], iteration:[0], done:[False], time:[0.05], fitness:[455.0000]
# 	[20  3 17 13 27  3  0 20  3 15 10 24 23 23 22 25  3  7  3  3  6 13 21  4// 21 25  1 14 24  7  4 29]...
#
# pop_size:[50], mutation_prob:[0.1], max_iters:[100000]
# runner_name:[ga], experiment_name:[GA_Exp], attempt:[101], iteration:[222], done:[True], time:[8.43], fitness:[491.0000]
# 	[ 3 25  4 14 19  9 18 26 28  3  5 27 17  0 11  1 25  2 16  8 10 31 29 22// 15  7  5 13 16 21 23  6]...
#
# ***************
# *** Run END ***
# ***************
# *****************
# *** Run START ***
# *****************
# pop_size:[50], mutation_prob:[0.25], max_iters:[100000]
# runner_name:[ga], experiment_name:[GA_Exp], attempt:[0], iteration:[0], done:[False], time:[0.04], fitness:[455.0000]
# 	[20  3 17 13 27  3  0 20  3 15 10 24 23 23 22 25  3  7  3  3  6 13 21  4// 21 25  1 14 24  7  4 29]...
#
# pop_size:[50], mutation_prob:[0.25], max_iters:[100000]
# runner_name:[ga], experiment_name:[GA_Exp], attempt:[101], iteration:[188], done:[True], time:[7.38], fitness:[490.0000]
# 	[ 8 22 13  6  2  5 11 17  3 19  9 31  2 27 18  1 29  1  3 28 14 10 28 25// 15 26  4 10 16  0 23  7]...
#
# ***************
# *** Run END ***
# ***************
# *****************
# *** Run START ***
# *****************
# pop_size:[50], mutation_prob:[0.5], max_iters:[100000]
# runner_name:[ga], experiment_name:[GA_Exp], attempt:[0], iteration:[0], done:[False], time:[0.04], fitness:[455.0000]
# 	[20  3 17 13 27  3  0 20  3 15 10 24 23 23 22 25  3  7  3  3  6 13 21  4// 21 25  1 14 24  7  4 29]...
#
# pop_size:[50], mutation_prob:[0.5], max_iters:[100000]
# runner_name:[ga], experiment_name:[GA_Exp], attempt:[101], iteration:[210], done:[True], time:[8.33], fitness:[492.0000]
# 	[15 20 11  8 16 27 23  0 28 13 31 10 26 14  4  1 29 25  6 29  3 13 18  7// 22 25  5 30  9 24 21  2]...
#
# ***************
# *** Run END ***
# ***************
# *****************
# *** Run START ***
# *****************
# pop_size:[200], mutation_prob:[0.1], max_iters:[100000]
# runner_name:[ga], experiment_name:[GA_Exp], attempt:[0], iteration:[0], done:[False], time:[0.15], fitness:[455.0000]
# 	[20  3 17 13 27  3  0 20  3 15 10 24 23 23 22 25  3  7  3  3  6 13 21  4// 21 25  1 14 24  7  4 29]...
#
# pop_size:[200], mutation_prob:[0.1], max_iters:[100000]
# runner_name:[ga], experiment_name:[GA_Exp], attempt:[101], iteration:[226], done:[True], time:[35.15], fitness:[495.0000]
# 	[24 21 27  8 12  5 13 20 17  0  2 22 30  1  4 11  1  3 16 31 19 25 23 29//  6 18 28 14  9 26 10  7]...
#
# ***************
# *** Run END ***
# ***************
# *****************
# *** Run START ***
# *****************
# pop_size:[200], mutation_prob:[0.25], max_iters:[100000]
# runner_name:[ga], experiment_name:[GA_Exp], attempt:[0], iteration:[0], done:[False], time:[0.14], fitness:[455.0000]
# 	[20  3 17 13 27  3  0 20  3 15 10 24 23 23 22 25  3  7  3  3  6 13 21  4// 21 25  1 14 24  7  4 29]...
#
# pop_size:[200], mutation_prob:[0.25], max_iters:[100000]
# runner_name:[ga], experiment_name:[GA_Exp], attempt:[101], iteration:[286], done:[True], time:[43.27], fitness:[492.0000]
# 	[19 24  7 12 24 29 14 22 25 27  4  2 28 11 18  2  0 31 13 30  1 23 15 20//  3 21 26  3 10  6 31 16]...
#
# ***************
# *** Run END ***
# ***************
# *****************
# *** Run START ***
# *****************
# pop_size:[200], mutation_prob:[0.5], max_iters:[100000]
# runner_name:[ga], experiment_name:[GA_Exp], attempt:[0], iteration:[0], done:[False], time:[0.14], fitness:[455.0000]
# 	[20  3 17 13 27  3  0 20  3 15 10 24 23 23 22 25  3  7  3  3  6 13 21  4// 21 25  1 14 24  7  4 29]...
#
# pop_size:[200], mutation_prob:[0.5], max_iters:[100000]
# runner_name:[ga], experiment_name:[GA_Exp], attempt:[101], iteration:[303], done:[True], time:[43.91], fitness:[495.0000]
# 	[17 10 12 31  8 16 25  2 14 30 28 26 11  3  1 15 19  2  7 21  4 29 23  9//  5 22 20  6  0 27 13 24]...
#
# ***************
# *** Run END ***
# ***************
# *****************
# *** Run START ***
# *****************
# pop_size:[500], mutation_prob:[0.1], max_iters:[100000]
# runner_name:[ga], experiment_name:[GA_Exp], attempt:[0], iteration:[0], done:[False], time:[0.33], fitness:[455.0000]
# 	[20  3 17 13 27  3  0 20  3 15 10 24 23 23 22 25  3  7  3  3  6 13 21  4// 21 25  1 14 24  7  4 29]...
#
# pop_size:[500], mutation_prob:[0.1], max_iters:[100000]
# runner_name:[ga], experiment_name:[GA_Exp], attempt:[101], iteration:[403], done:[True], time:[149.26], fitness:[495.0000]
# 	[20 25 31  2 12 24  1  8 10 18 15 27 29 11  5 21 30 11  3 26 23 14  9  0// 28 22  4  7 16 13 19  6]...
#
# ***************
# *** Run END ***
# ***************
# *****************
# *** Run START ***
# *****************
# pop_size:[500], mutation_prob:[0.25], max_iters:[100000]
# runner_name:[ga], experiment_name:[GA_Exp], attempt:[0], iteration:[0], done:[False], time:[0.34], fitness:[455.0000]
# 	[20  3 17 13 27  3  0 20  3 15 10 24 23 23 22 25  3  7  3  3  6 13 21  4// 21 25  1 14 24  7  4 29]...
#
# pop_size:[500], mutation_prob:[0.25], max_iters:[100000]
# runner_name:[ga], experiment_name:[GA_Exp], attempt:[101], iteration:[303], done:[True], time:[109.54], fitness:[494.0000]
# 	[ 2  5 22  0 12 16 24 13 23  8  4 28 31 29  9 11 21 27  1 26 20 14 10 15//  3  9  7 30 19  0  6 17]...
#
# ***************
# *** Run END ***
# ***************
# *****************
# *** Run START ***
# *****************
# pop_size:[500], mutation_prob:[0.5], max_iters:[100000]
# runner_name:[ga], experiment_name:[GA_Exp], attempt:[0], iteration:[0], done:[False], time:[0.33], fitness:[455.0000]
# 	[20  3 17 13 27  3  0 20  3 15 10 24 23 23 22 25  3  7  3  3  6 13 21  4// 21 25  1 14 24  7  4 29]...
#
# pop_size:[500], mutation_prob:[0.5], max_iters:[100000]
# runner_name:[ga], experiment_name:[GA_Exp], attempt:[101], iteration:[465], done:[True], time:[166.83], fitness:[493.0000]
# 	[31 20 18 29 21  9  5 19 28  3 13  8  1 26  2  2 11 25 10  5 30 23 27  6// 14 16  4  7 12 25 15 24]...
#
# ***************
# *** Run END ***
# ***************
# Run time: 572.172726852
# CPU times: user 9min 31s, sys: 170 ms, total: 9min 32s
# Wall time: 9min 32s

# %%
ga_run_stats
# Out:
#     Iteration  Fitness        Time  ... Population Size  Mutation Rate  max_iters
# 0           0    455.0    0.047976  ...              50           0.10     100000
# 1      100000    491.0    8.434515  ...              50           0.10     100000
# 2           0    455.0    0.037131  ...              50           0.25     100000
# 3      100000    490.0    7.379052  ...              50           0.25     100000
# 4           0    455.0    0.040590  ...              50           0.50     100000
# 5      100000    492.0    8.333684  ...              50           0.50     100000
# 6           0    455.0    0.146551  ...             200           0.10     100000
# 7      100000    495.0   35.147863  ...             200           0.10     100000
# 8           0    455.0    0.139874  ...             200           0.25     100000
# 9      100000    492.0   43.273658  ...             200           0.25     100000
# 10          0    455.0    0.140449  ...             200           0.50     100000
# 11     100000    495.0   43.913625  ...             200           0.50     100000
# 12          0    455.0    0.326267  ...             500           0.10     100000
# 13     100000    495.0  149.260777  ...             500           0.10     100000
# 14          0    455.0    0.342067  ...             500           0.25     100000
# 15     100000    494.0  109.538141  ...             500           0.25     100000
# 16          0    455.0    0.334852  ...             500           0.50     100000
# 17     100000    493.0  166.834131  ...             500           0.50     100000
#
# [18 rows x 7 columns]

# %%
ga_run_curves
# Out:
#       Iteration        Time  Fitness  Population Size  Mutation Rate  max_iters
# 0             0    0.047976    474.0               50            0.1     100000
# 1             1    0.085445    474.0               50            0.1     100000
# 2             2    0.123949    474.0               50            0.1     100000
# 3             3    0.163355    477.0               50            0.1     100000
# 4             4    0.201628    477.0               50            0.1     100000
# ...         ...         ...      ...              ...            ...        ...
# 2601       2601  162.139012    493.0              500            0.5     100000
# 2602       2602  162.509045    493.0              500            0.5     100000
# 2603       2603  162.863462    493.0              500            0.5     100000
# 2604       2604  163.215257    493.0              500            0.5     100000
# 2605       2605  163.572824    493.0              500            0.5     100000
#
# [2606 rows x 6 columns]

# %%
last_iters = ga_run_stats[ga_run_stats.Iteration != 0].reset_index()
print("Max and mean")
print(last_iters.Fitness.max(), last_iters.Fitness.mean(), last_iters.Time.mean())
print(last_iters.groupby("Mutation Rate").Fitness.mean())
print(last_iters.groupby("Population Size").Fitness.mean())
print(last_iters.groupby("Population Size").Time.mean())
# Out:
# Max and mean
# 495.0 493.0 63.56838289911111
# Mutation Rate
# 0.10    493.666667
# 0.25    492.000000
# 0.50    493.333333
# Name: Fitness, dtype: float64
# Population Size
# 50     491.0
# 200    494.0
# 500    494.0
# Name: Fitness, dtype: float64
# Population Size
# 50       8.049084
# 200     40.778382
# 500    141.877683
# Name: Time, dtype: float64

# %%
best_index_in_curve = ga_run_curves.Fitness.idxmax()
best_decay = ga_run_curves.iloc[best_index_in_curve]['Mutation Rate']
best_curve = ga_run_curves.loc[ga_run_curves['Mutation Rate'] == best_decay, :]
best_curve.reset_index(inplace=True)
best_decay
# Out:
# 0.1

# %%
ax = best_curve.Fitness.plot(lw=2, colormap='jet', marker='.', markersize=2, 
                             figsize=(12,8), grid=1,
                             title='Best Genetic Algorithm')
ax.set_xlabel("Iterations")
ax.set_ylabel("Fitness Value")
# Out:
# Text(0, 0.5, 'Fitness Value')

# %% [markdown]
# ## MIMIC

# %%
mmc = mlrose_hiive.MIMICRunner(problem=problem,
                  experiment_name="MMC_Exp",
                  seed=44,
                  iteration_list=[100000],
                  max_attempts=100,
                  population_sizes=[50, 200, 500],
                  keep_percent_list=[0.25, 0.5, 0.75],
                  use_fast_mimic=True)

# the two data frames will contain the results
mmc_run_stats, mmc_run_curves = mmc.run()
# Out:
# Running mimic
# *****************
# *** Run START ***
# *****************
# use_fast_mimic:[True], pop_size:[50], keep_pct:[0.25], max_iters:[100000]
# runner_name:[mimic], experiment_name:[MMC_Exp], attempt:[0], iteration:[0], done:[False], time:[0.04], fitness:[455.0000]
# 	[20  3 17 13 27  3  0 20  3 15 10 24 23 23 22 25  3  7  3  3  6 13 21  4// 21 25  1 14 24  7  4 29]...
#
# use_fast_mimic:[True], pop_size:[50], keep_pct:[0.25], max_iters:[100000]
# runner_name:[mimic], experiment_name:[MMC_Exp], attempt:[101], iteration:[101], done:[True], time:[22.12], fitness:[474.0000]
# 	[26. 22. 13. 31. 29.  5. 11. 17.  3. 19.  2. 11.  7.  5. 18. 26. 29. 18.// 14. 28. 14. 10. 28. 25. 15. 22.  4. 10.  5.  0. 23. 11.]...
#
# ***************
# *** Run END ***
# ***************
# *****************
# *** Run START ***
# *****************
# use_fast_mimic:[True], pop_size:[50], keep_pct:[0.5], max_iters:[100000]
# runner_name:[mimic], experiment_name:[MMC_Exp], attempt:[0], iteration:[0], done:[False], time:[0.05], fitness:[455.0000]
# 	[20  3 17 13 27  3  0 20  3 15 10 24 23 23 22 25  3  7  3  3  6 13 21  4// 21 25  1 14 24  7  4 29]...
#
# use_fast_mimic:[True], pop_size:[50], keep_pct:[0.5], max_iters:[100000]
# runner_name:[mimic], experiment_name:[MMC_Exp], attempt:[101], iteration:[101], done:[True], time:[21.94], fitness:[474.0000]
# 	[26. 22. 13. 31. 29.  5.  8. 17.  3. 19.  2. 11.  7.  8. 18. 26. 29. 18.// 14. 28. 14. 10. 28. 25. 15. 22.  4. 10.  5.  0. 27. 11.]...
#
# ***************
# *** Run END ***
# ***************
# *****************
# *** Run START ***
# *****************
# use_fast_mimic:[True], pop_size:[50], keep_pct:[0.75], max_iters:[100000]
# runner_name:[mimic], experiment_name:[MMC_Exp], attempt:[0], iteration:[0], done:[False], time:[0.03], fitness:[455.0000]
# 	[20  3 17 13 27  3  0 20  3 15 10 24 23 23 22 25  3  7  3  3  6 13 21  4// 21 25  1 14 24  7  4 29]...
#
# use_fast_mimic:[True], pop_size:[50], keep_pct:[0.75], max_iters:[100000]
# runner_name:[mimic], experiment_name:[MMC_Exp], attempt:[101], iteration:[103], done:[True], time:[22.01], fitness:[476.0000]
# 	[11. 19.  5. 20. 11.  3. 27.  0. 27. 21. 30. 13. 13.  8. 14.  7. 10.  2.// 31. 10. 28. 31. 29. 27.  3. 22. 26. 21.  0. 10.  1. 18.]...
#
# ***************
# *** Run END ***
# ***************
# *****************
# *** Run START ***
# *****************
# use_fast_mimic:[True], pop_size:[200], keep_pct:[0.25], max_iters:[100000]
# runner_name:[mimic], experiment_name:[MMC_Exp], attempt:[0], iteration:[0], done:[False], time:[0.13], fitness:[455.0000]
# 	[20  3 17 13 27  3  0 20  3 15 10 24 23 23 22 25  3  7  3  3  6 13 21  4// 21 25  1 14 24  7  4 29]...
#
# use_fast_mimic:[True], pop_size:[200], keep_pct:[0.25], max_iters:[100000]
# runner_name:[mimic], experiment_name:[MMC_Exp], attempt:[101], iteration:[104], done:[True], time:[52.39], fitness:[480.0000]
# 	[26. 13. 17. 30. 12. 18. 15. 30. 24. 30.  8. 31. 29. 16. 16.  7.  1. 27.//  3. 19.  7. 27. 25. 20. 28. 20.  5. 13.  4. 18.  5.  3.]...
#
# ***************
# *** Run END ***
# ***************
# *****************
# *** Run START ***
# *****************
# use_fast_mimic:[True], pop_size:[200], keep_pct:[0.5], max_iters:[100000]
# runner_name:[mimic], experiment_name:[MMC_Exp], attempt:[0], iteration:[0], done:[False], time:[0.14], fitness:[455.0000]
# 	[20  3 17 13 27  3  0 20  3 15 10 24 23 23 22 25  3  7  3  3  6 13 21  4// 21 25  1 14 24  7  4 29]...
#
# use_fast_mimic:[True], pop_size:[200], keep_pct:[0.5], max_iters:[100000]
# runner_name:[mimic], experiment_name:[MMC_Exp], attempt:[101], iteration:[114], done:[True], time:[57.73], fitness:[484.0000]
# 	[31. 13. 29.  0. 11.  5.  7. 15. 27. 16.  9. 26. 17.  8. 24.  3.  1.  6.// 31. 28. 19.  5. 28. 17. 22.  9.  6. 30. 20. 23.  4.  2.]...
#
# ***************
# *** Run END ***
# ***************
# *****************
# *** Run START ***
# *****************
# use_fast_mimic:[True], pop_size:[200], keep_pct:[0.75], max_iters:[100000]
# runner_name:[mimic], experiment_name:[MMC_Exp], attempt:[0], iteration:[0], done:[False], time:[0.13], fitness:[455.0000]
# 	[20  3 17 13 27  3  0 20  3 15 10 24 23 23 22 25  3  7  3  3  6 13 21  4// 21 25  1 14 24  7  4 29]...
#
# use_fast_mimic:[True], pop_size:[200], keep_pct:[0.75], max_iters:[100000]
# runner_name:[mimic], experiment_name:[MMC_Exp], attempt:[101], iteration:[101], done:[True], time:[50.76], fitness:[477.0000]
# 	[13. 31.  6. 30. 20.  0. 16. 26. 17.  3.  7. 20. 10. 22. 25.  5.  2. 30.//  1.  8. 16. 21. 18. 15. 19. 23. 14. 15. 29.  1.  7. 18.]...
#
# ***************
# *** Run END ***
# ***************
# *****************
# *** Run START ***
# *****************
# use_fast_mimic:[True], pop_size:[500], keep_pct:[0.25], max_iters:[100000]
# runner_name:[mimic], experiment_name:[MMC_Exp], attempt:[0], iteration:[0], done:[False], time:[0.34], fitness:[455.0000]
# 	[20  3 17 13 27  3  0 20  3 15 10 24 23 23 22 25  3  7  3  3  6 13 21  4// 21 25  1 14 24  7  4 29]...
#
# use_fast_mimic:[True], pop_size:[500], keep_pct:[0.25], max_iters:[100000]
# runner_name:[mimic], experiment_name:[MMC_Exp], attempt:[101], iteration:[107], done:[True], time:[118.46], fitness:[483.0000]
# 	[24.  0.  3. 11. 13.  3. 14. 12. 14. 26. 17.  8. 15. 31.  7. 27. 25. 29.//  5.  9. 19. 13.  8.  1. 28.  6. 22. 29.  4. 23. 30. 16.]...
#
# ***************
# *** Run END ***
# ***************
# *****************
# *** Run START ***
# *****************
# use_fast_mimic:[True], pop_size:[500], keep_pct:[0.5], max_iters:[100000]
# runner_name:[mimic], experiment_name:[MMC_Exp], attempt:[0], iteration:[0], done:[False], time:[0.34], fitness:[455.0000]
# 	[20  3 17 13 27  3  0 20  3 15 10 24 23 23 22 25  3  7  3  3  6 13 21  4// 21 25  1 14 24  7  4 29]...
#
# use_fast_mimic:[True], pop_size:[500], keep_pct:[0.5], max_iters:[100000]
# runner_name:[mimic], experiment_name:[MMC_Exp], attempt:[101], iteration:[117], done:[True], time:[130.55], fitness:[484.0000]
# 	[17.  6. 22.  8. 19.  3. 30. 26. 24.  3. 12. 31. 16. 24. 27. 29. 13.  4.// 13.  1. 11. 30. 28. 23.  2.  4.  9. 14.  2. 18. 15.  7.]...
#
# ***************
# *** Run END ***
# ***************
# *****************
# *** Run START ***
# *****************
# use_fast_mimic:[True], pop_size:[500], keep_pct:[0.75], max_iters:[100000]
# runner_name:[mimic], experiment_name:[MMC_Exp], attempt:[0], iteration:[0], done:[False], time:[0.34], fitness:[455.0000]
# 	[20  3 17 13 27  3  0 20  3 15 10 24 23 23 22 25  3  7  3  3  6 13 21  4// 21 25  1 14 24  7  4 29]...
#
# use_fast_mimic:[True], pop_size:[500], keep_pct:[0.75], max_iters:[100000]
# runner_name:[mimic], experiment_name:[MMC_Exp], attempt:[101], iteration:[127], done:[True], time:[149.53], fitness:[483.0000]
# 	[22.  0. 11. 20.  6. 12.  8. 26.  5. 14. 14. 21. 18. 25. 17. 30. 10.  3.// 19. 27. 31. 26. 13.  4. 12. 17. 13.  2. 23.  2. 19.  9.]...
#
# ***************
# *** Run END ***
# ***************
# Run time: 625.5432375299999

# %%
mmc_run_stats
# Out:
#     Iteration  Fitness        Time  ... Population Size  Keep Percent  max_iters
# 0           0    455.0    0.037465  ...              50          0.25     100000
# 1      100000    474.0   22.124910  ...              50          0.25     100000
# 2           0    455.0    0.051886  ...              50          0.50     100000
# 3      100000    474.0   21.943258  ...              50          0.50     100000
# 4           0    455.0    0.034483  ...              50          0.75     100000
# 5      100000    476.0   22.010290  ...              50          0.75     100000
# 6           0    455.0    0.134156  ...             200          0.25     100000
# 7      100000    480.0   52.388859  ...             200          0.25     100000
# 8           0    455.0    0.136569  ...             200          0.50     100000
# 9      100000    484.0   57.733046  ...             200          0.50     100000
# 10          0    455.0    0.131871  ...             200          0.75     100000
# 11     100000    477.0   50.756439  ...             200          0.75     100000
# 12          0    455.0    0.335114  ...             500          0.25     100000
# 13     100000    483.0  118.460327  ...             500          0.25     100000
# 14          0    455.0    0.343221  ...             500          0.50     100000
# 15     100000    484.0  130.551249  ...             500          0.50     100000
# 16          0    455.0    0.338594  ...             500          0.75     100000
# 17     100000    483.0  149.527163  ...             500          0.75     100000
#
# [18 rows x 8 columns]

# %%
mmc_run_curves
# Out:
#      Iteration        Time  Fitness  ...  Population Size  Keep Percent  max_iters
# 0            0    0.037465    474.0  ...               50          0.25     100000
# 1            1    0.248342    474.0  ...               50          0.25     100000
# 2            2    0.428119    474.0  ...               50          0.25     100000
# 3            3    0.608520    474.0  ...               50          0.25     100000
# 4            4    0.841239    474.0  ...               50          0.25     100000
# ..         ...         ...      ...  ...              ...           ...        ...
# 970        970  134.193978    483.0  ...              500          0.75     100000
# 971        971  135.378359    483.0  ...              500          0.75     100000
# 972        972  136.535912    483.0  ...              500          0.75     100000
# 973        973  137.691432    483.0  ...              500          0.75     100000
# 974        974  138.836826    483.0  ...              500          0.75     100000
#
# [975 rows x 7 columns]

# %%
last_iters = mmc_run_stats[mmc_run_stats.Iteration != 0].reset_index()
print("Max and mean")
print(last_iters.Fitness.max(), last_iters.Fitness.mean(), last_iters.Time.mean())
print(last_iters.groupby("Keep Percent").Fitness.mean())
print(last_iters.groupby("Population Size").Fitness.mean())
print(last_iters.groupby("Population Size").Time.mean())
# Out:
# Max and mean
# 484.0 479.44444444444446 69.49950451222223
# Keep Percent
# 0.25    479.000000
# 0.50    480.666667
# 0.75    478.666667
# Name: Fitness, dtype: float64
# Population Size
# 50     474.666667
# 200    480.333333
# 500    483.333333
# Name: Fitness, dtype: float64
# Population Size
# 50      22.026153
# 200     53.626115
# 500    132.846246
# Name: Time, dtype: float64

# %%
best_index_in_curve = mmc_run_stats.Fitness.idxmax()
best_decay = mmc_run_stats.iloc[best_index_in_curve]['Population Size']
best_curve = mmc_run_stats.loc[mmc_run_stats['Population Size'] == best_decay, :]
best_curve.reset_index(inplace=True)
best_decay
# Out:
# 200

# %%
ax = best_curve.Fitness.plot(lw=2, colormap='jet', marker='.', markersize=2, 
                             figsize=(12,8), grid=1,
                             title='Best MIMIC Algorithm')
ax.set_xlabel("Iterations")
ax.set_ylabel("Fitness Value")
# Out:
# Text(0, 0.5, 'Fitness Value')

# %%
rhc_run_stats.to_pickle("./n_queen_rhc_run_stats.pkl")
rhc_run_curves.to_pickle("./n_queen_rhc_run_curves.pkl")
sa_run_stats.to_pickle("./n_queen_sa_run_stats.pkl")
sa_run_curves.to_pickle("./n_queen_sa_run_curves.pkl")
ga_run_stats.to_pickle("./n_queen_ga_run_stats.pkl")
ga_run_curves.to_pickle("./n_queen_ga_run_curves.pkl")
mmc_run_stats.to_pickle("./n_queen_mmc_run_stats.pkl")
mmc_run_curves.to_pickle("./n_queen_mmc_run_curves.pkl")
